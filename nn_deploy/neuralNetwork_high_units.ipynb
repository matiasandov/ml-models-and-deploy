# %%
import pandas as pd 
import tensorflow
from tensorflow import keras
from keras import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

df = pd.read_csv("../Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df = df.drop(["RowNumber", "CustomerId", "Surname"], axis=1)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
le = LabelEncoder()
for col in df.select_dtypes("object"):
    df[col] = le.fit_transform(df[col])
df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
Y = df["Exited"]
X = df.drop(["Exited"], axis=1)
Xtrain, Xtest,ytrain,ytest = train_test_split(X,Y, test_size=0.2, shuffle=True, random_state=42)

# %%
#scaling es muy importante para gardient descent en NN, SVM, distance measurementes, knn 
scaler = MinMaxScaler()
#important to apply it after splitting bc it affects data leakage and overfitting if combined with xtest , por eso debe ser independiente
Xtrain = scaler.fit_transform(Xtrain)
#se aplican los parameters learned from the training set
Xtest = scaler.transform(Xtest)

# %%
import tensorflow as tf
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
import numpy as np


unique_classes = np.unique(ytrain)

# %%
from keras.callbacks import EarlyStopping


early_stopping = EarlyStopping(
    monitor='recall',    # Metric to monitor
    patience=10,            # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restore model weights from the epoch with the best value of the monitored quantity
    mode = "max"
    
)

model = Sequential()
model.add(Dense(units=400,  activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(units=600, activation="relu" ))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(units=300, activation="relu"))
model.add(BatchNormalization())
model.add(Dense(units=100, activation="relu"))
model.add(BatchNormalization())
model.add(Dense(units=100, activation="relu"))
model.add(BatchNormalization())
model.add(Dense(units=1, activation="sigmoid"))

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["recall"])
model.fit(x=Xtrain, y=ytrain, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.6413 - recall: 0.4288 - val_loss: 0.4860 - val_recall: 0.0000e+00
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4167 - recall: 0.3701 - val_loss: 0.4197 - val_recall: 0.2422
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3971 - recall: 0.3988 - val_loss: 0.3663 - val_recall: 0.3758
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4045 - recall: 0.3646 - val_loss: 0.3666 - val_recall: 0.4255
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3757 - recall: 0.3946 - val_loss: 0.3822 - val_recall: 0.5062
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3802 - recall: 0.4283 - val_loss: 0.3637 - val_recall: 0.4317
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3709 - recall: 0.4115 - val_loss: 0.3648 - val_recall: 0.4627
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3560 - recall: 0.4353 - val_loss: 0.3649 - val_recall: 0.3944
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3587 - recall: 0.4400 - val_loss: 0.3525 - val_recall: 0.3882
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3724 - recall: 0.4055 - val_loss: 0.3505 - val_recall: 0.4814
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3632 - recall: 0.4705 - val_loss: 0.3543 - val_recall: 0.3851
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3750 - recall: 0.4219 - val_loss: 0.3559 - val_recall: 0.4534
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3531 - recall: 0.4649 - val_loss: 0.3648 - val_recall: 0.3540
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3634 - recall: 0.4327 - val_loss: 0.3595 - val_recall: 0.3975
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3567 - recall: 0.4270 - val_loss: 0.3608 - val_recall: 0.3261
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3504 - recall: 0.4551 - val_loss: 0.3587 - val_recall: 0.4379
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3414 - recall: 0.4796 - val_loss: 0.3417 - val_recall: 0.4286
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3502 - recall: 0.4539 - val_loss: 0.3467 - val_recall: 0.5093
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3559 - recall: 0.4757 - val_loss: 0.3555 - val_recall: 0.4348
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3526 - recall: 0.4859 - val_loss: 0.3571 - val_recall: 0.4596
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3030 - recall: 0.5265 - val_loss: 0.3691 - val_recall: 0.4938
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3128 - recall: 0.5499 - val_loss: 0.3619 - val_recall: 0.4472
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3188 - recall: 0.5453 - val_loss: 0.3657 - val_recall: 0.4441
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2995 - recall: 0.5264 - val_loss: 0.3692 - val_recall: 0.4814
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3152 - recall: 0.5014 - val_loss: 0.3688 - val_recall: 0.4317
# Epoch 64/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3064 - recall: 0.5309 - val_loss: 0.3685 - val_recall: 0.5000
# Epoch 65/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3178 - recall: 0.5472 - val_loss: 0.3676 - val_recall: 0.4627
# Epoch 66/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3075 - recall: 0.5492 - val_loss: 0.3628 - val_recall: 0.4472
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3001 - recall: 0.5657 - val_loss: 0.3751 - val_recall: 0.4410
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3063 - recall: 0.5488 - val_loss: 0.3735 - val_recall: 0.4379
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3024 - recall: 0.5480 - val_loss: 0.3704 - val_recall: 0.5155
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2970 - recall: 0.5551 - val_loss: 0.3637 - val_recall: 0.4317
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3001 - recall: 0.5679 - val_loss: 0.3772 - val_recall: 0.4503
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3126 - recall: 0.5187 - val_loss: 0.3700 - val_recall: 0.5093
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3122 - recall: 0.5513 - val_loss: 0.3666 - val_recall: 0.4410
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3003 - recall: 0.5494 - val_loss: 0.3718 - val_recall: 0.4006
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2914 - recall: 0.5529 - val_loss: 0.3648 - val_recall: 0.4534
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2938 - recall: 0.5618 - val_loss: 0.3824 - val_recall: 0.3913
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3055 - recall: 0.5051 - val_loss: 0.3804 - val_recall: 0.5031
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2882 - recall: 0.5837 - val_loss: 0.3754 - val_recall: 0.4720
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2901 - recall: 0.5581 - val_loss: 0.3919 - val_recall: 0.4472
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2939 - recall: 0.5700 - val_loss: 0.3791 - val_recall: 0.4472
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3034 - recall: 0.5375 - val_loss: 0.3753 - val_recall: 0.5248
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2878 - recall: 0.5533 - val_loss: 0.3822 - val_recall: 0.4503
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2858 - recall: 0.5924 - val_loss: 0.3892 - val_recall: 0.4689
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2939 - recall: 0.5460 - val_loss: 0.3737 - val_recall: 0.4720
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2988 - recall: 0.5756 - val_loss: 0.3873 - val_recall: 0.3820
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2865 - recall: 0.5698 - val_loss: 0.4022 - val_recall: 0.3540
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2905 - recall: 0.5137 - val_loss: 0.3816 - val_recall: 0.4969
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2858 - recall: 0.5638 - val_loss: 0.3823 - val_recall: 0.5093
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2883 - recall: 0.5891 - val_loss: 0.3822 - val_recall: 0.4534
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2930 - recall: 0.5509 - val_loss: 0.3875 - val_recall: 0.4317
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2902 - recall: 0.5292 - val_loss: 0.3871 - val_recall: 0.4534
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2848 - recall: 0.5616 - val_loss: 0.3838 - val_recall: 0.5000
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2804 - recall: 0.5972 - val_loss: 0.3805 - val_recall: 0.4658

# %%
loss, recall = model.evaluate(Xtest, ytest)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3604 - recall: 0.5464

# %%
ypred = (model.predict(Xtest) > 0.5).astype("int32")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
ypred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1607
#            1       0.68      0.51      0.59       393
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
import pickle
with open("neural3.pkl", "wb") as file:
    pickle.dump(model, file)
