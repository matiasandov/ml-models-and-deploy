# %%
import pandas as pd 
import tensorflow
from tensorflow import keras
from keras import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

df = pd.read_csv("../Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df = df.drop(["RowNumber", "CustomerId", "Surname"], axis=1)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
le = LabelEncoder()
for col in df.select_dtypes("object"):
    df[col] = le.fit_transform(df[col])
df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
Y = df["Exited"]
X = df.drop(["Exited"], axis=1)
Xtrain, Xtest,ytrain,ytest = train_test_split(X,Y, test_size=0.2, shuffle=True, random_state=42)

# %%
#scaling es muy importante para gardient descent en NN, SVM, distance measurementes, knn 
scaler = MinMaxScaler()
#important to apply it after splitting bc it affects data leakage and overfitting if combined with xtest , por eso debe ser independiente
Xtrain = scaler.fit_transform(Xtrain)
#se aplican los parameters learned from the training set
Xtest = scaler.transform(Xtest)

# %%
import tensorflow as tf
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.utils import class_weight
import numpy as np


unique_classes = np.unique(ytrain)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint


early_stopping = EarlyStopping(
    monitor='recall',    # Metric to monitor
    patience=7,            # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True,  # Restore model weights from the epoch with the best value of the monitored quantity
    mode = "max"
    
)

model = Sequential()
model.add(Dense(units=500,  activation="relu",  input_shape = (10,)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(units=400, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(units=400, activation="relu"))
model.add(BatchNormalization())
model.add(Dense(units=400, activation="relu"))
model.add(BatchNormalization())
model.add(Dense(units=100, activation="relu"))
model.add(BatchNormalization())
model.add(Dense(units=1, activation="sigmoid"))

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["recall"])
model.fit(x=Xtrain, y=ytrain, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# C:\Users\matts\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.6968 - recall: 0.4186 - val_loss: 0.4883 - val_recall: 0.0000e+00
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4170 - recall: 0.3569 - val_loss: 0.4455 - val_recall: 0.3230
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4040 - recall: 0.3816 - val_loss: 0.3672 - val_recall: 0.3571
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3909 - recall: 0.3875 - val_loss: 0.3697 - val_recall: 0.4845
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3697 - recall: 0.4411 - val_loss: 0.3621 - val_recall: 0.4752
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3715 - recall: 0.4176 - val_loss: 0.3738 - val_recall: 0.5311
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3635 - recall: 0.4357 - val_loss: 0.3550 - val_recall: 0.4503
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3700 - recall: 0.4185 - val_loss: 0.3590 - val_recall: 0.4037
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3561 - recall: 0.4188 - val_loss: 0.3608 - val_recall: 0.4130
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3530 - recall: 0.4431 - val_loss: 0.3579 - val_recall: 0.4565
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3557 - recall: 0.4241 - val_loss: 0.3557 - val_recall: 0.3944
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3609 - recall: 0.4392 - val_loss: 0.3586 - val_recall: 0.4534
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3617 - recall: 0.4273 - val_loss: 0.3427 - val_recall: 0.3975
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3499 - recall: 0.4026 - val_loss: 0.3548 - val_recall: 0.4907
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3509 - recall: 0.4747 - val_loss: 0.3443 - val_recall: 0.4752
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3628 - recall: 0.4361 - val_loss: 0.3465 - val_recall: 0.4348
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3549 - recall: 0.4372 - val_loss: 0.3594 - val_recall: 0.4379
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3539 - recall: 0.4336 - val_loss: 0.3580 - val_recall: 0.4472
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3460 - recall: 0.4727 - val_loss: 0.3545 - val_recall: 0.3882
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3516 - recall: 0.4761 - val_loss: 0.3453 - val_recall: 0.4317
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3491 - recall: 0.4305 - val_loss: 0.3530 - val_recall: 0.5248
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3576 - recall: 0.4566 - val_loss: 0.3511 - val_recall: 0.4658

# %%
loss, recall = model.evaluate(Xtest, ytest)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3416 - recall: 0.5352

# %%
ypred = (model.predict(Xtest) > 0.5).astype("int32")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
ypred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      1607
#            1       0.69      0.54      0.60       393
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.74      0.76      2000
# weighted avg       0.85      0.86      0.86      2000

# %%
import pickle
with open("neural2.pkl", "wb") as file:
    pickle.dump(model, file)
