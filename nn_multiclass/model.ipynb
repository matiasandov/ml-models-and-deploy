# %%
import pandas as pd
import tensorflow
import sklearn
import keras

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
#los uno porque sera mas facil procesar todo asi
df = pd.concat([train, test], axis=0)

# %%
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 2622  467954    Male           No   29        No     Healthcare
# 2623  467958  Female           No   35       Yes         Doctor
# 2624  467960  Female           No   53       Yes  Entertainment
# 2625  467961    Male          Yes   47       Yes      Executive
# 2626  467968  Female           No   43       Yes     Healthcare
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
for col in df.columns:
    if df[col].isnull().sum() > 0:
        print("__________")
        print(col)
        print(df[col].value_counts())
# Out:
# __________
# Ever_Married
# Yes    6163
# No     4342
# Name: Ever_Married, dtype: int64
# __________
# Graduated
# Yes    6570
# No     4023
# Name: Graduated, dtype: int64
# __________
# Profession
# Artist           3318
# Healthcare       1750
# Entertainment    1250
# Engineer          935
# Doctor            930
# Lawyer            844
# Executive         775
# Marketing         403
# Homemaker         328
# Name: Profession, dtype: int64
# __________
# Work_Experience
# 1.0     3127
# 0.0     3087
# 9.0      613
# 8.0      612
# 2.0      373
# 4.0      346
# 3.0      337
# 5.0      270
# 6.0      265
# 7.0      256
# 14.0      66
# 10.0      64
# 11.0      64
# 12.0      60
# 13.0      57
# Name: Work_Experience, dtype: int64
# __________
# Family_Size
# 2.0    3158
# 1.0    1965
# 3.0    1952
# 4.0    1823
# 5.0     812
# 6.0     290
# 7.0     122
# 8.0      65
# 9.0      60
# Name: Family_Size, dtype: int64
# __________
# Var_1
# Cat_6    6910
# Cat_4    1475
# ...

# %%
df[df["Family_Size"].isna()]
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 12    461230  Female           No   19        No   Executive              0.0
# 33    467010    Male           No   26        No   Homemaker              9.0
# 59    460881    Male          Yes   72       Yes      Lawyer              1.0
# 112   467758  Female          Yes   50       Yes      Doctor              1.0
# 126   466295  Female          Yes   42        No    Engineer              0.0
# ...      ...     ...          ...  ...       ...         ...              ...
# 2452  467385    Male           No   53        No      Artist              1.0
# 2453  467389    Male           No   42        No    Engineer              0.0
# 2496  467518    Male           No   22        No      Doctor              1.0
# 2507  467570    Male           No   18        No  Healthcare             14.0
# 2520  467612    Male          Yes   70       Yes   Executive              0.0
#
# ...

# %%
#I can observe most of them are females who probably just never executed their profession
df[df["Work_Experience"].isna() ]
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 1     462643  Female          Yes   38       Yes       Engineer
# 4     462669  Female          Yes   40       Yes  Entertainment
# 13    459573    Male          Yes   70        No         Lawyer
# 39    467442    Male          Yes   56       Yes         Artist
# 45    463156  Female          Yes   79        No         Lawyer
# ...      ...     ...          ...  ...       ...            ...
# 2547  467706  Female          Yes   35       Yes         Artist
# 2572  467798  Female           No   23        No            NaN
# 2588  467861  Female           No   29        No         Artist
# 2593  467879  Female          Yes   51       Yes         Artist
# 2624  467960  Female           No   53       Yes  Entertainment
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 1                 NaN        Average          3.0  Cat_4            A
# ...

# %%
df["Graduated"] = df["Graduated"].fillna("Unknown")
df["Profession"] = df["Profession"].fillna("Other")

df["Work_Experience"] = df["Work_Experience"].fillna(0.0)
df["Family_Size"] = df["Family_Size"].fillna(1.0)
df["Var_1"] = df["Var_1"].fillna("Cat_8")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10695 entries, 0 to 2626
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               10695 non-null  int64
#  1   Gender           10695 non-null  object
#  2   Ever_Married     10505 non-null  object
#  3   Age              10695 non-null  int64
#  4   Graduated        10695 non-null  object
#  5   Profession       10695 non-null  object
#  6   Work_Experience  10695 non-null  float64
#  7   Spending_Score   10695 non-null  object
#  8   Family_Size      10695 non-null  float64
#  9   Var_1            10695 non-null  object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1002.7+ KB

# %%
df = df.drop(["ID"], axis=1)
df
# Out:
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0       Male           No   22        No     Healthcare              1.0
# 1     Female          Yes   38       Yes       Engineer              0.0
# 2     Female          Yes   67       Yes       Engineer              1.0
# 3       Male          Yes   67       Yes         Lawyer              0.0
# 4     Female          Yes   40       Yes  Entertainment              0.0
# ...      ...          ...  ...       ...            ...              ...
# 2622    Male           No   29        No     Healthcare              9.0
# 2623  Female           No   35       Yes         Doctor              1.0
# 2624  Female           No   53       Yes  Entertainment              0.0
# 2625    Male          Yes   47       Yes      Executive              1.0
# 2626  Female           No   43       Yes     Healthcare              9.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

le = LabelEncoder()
for col in df.select_dtypes("object"):
    df[col] = le.fit_transform(df[col])

df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5              1.0
# 1          0             1   38          2           2              0.0
# 2          0             1   67          2           2              1.0
# 3          1             1   67          2           7              0.0
# 4          0             1   40          2           3              0.0
# ...      ...           ...  ...        ...         ...              ...
# 2622       1             0   29          0           5              9.0
# 2623       0             0   35          2           1              1.0
# 2624       0             0   53          2           3              0.0
# 2625       1             1   47          2           4              1.0
# 2626       0             0   43          2           5              9.0
#
#       Spending_Score  Family_Size  Var_1  Segmentation
# ...

# %%
#no me sirve de nada tener el test porque no esta etiquetado
df = df[df["Segmentation"] != 4]
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5              1.0
# 1          0             1   38          2           2              0.0
# 2          0             1   67          2           2              1.0
# 3          1             1   67          2           7              0.0
# 4          0             1   40          2           3              0.0
# ...      ...           ...  ...        ...         ...              ...
# 8063       1             0   22          0           9              0.0
# 8064       1             0   35          0           4              3.0
# 8065       0             0   33          2           5              1.0
# 8066       0             0   27          2           5              1.0
# 8067       1             1   37          2           4              0.0
#
#       Spending_Score  Family_Size  Var_1  Segmentation
# ...

# %%
df = df.drop_duplicates(ignore_index=True)
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5              1.0
# 1          0             1   38          2           2              0.0
# 2          0             1   67          2           2              1.0
# 3          1             1   67          2           7              0.0
# 4          0             1   40          2           3              0.0
# ...      ...           ...  ...        ...         ...              ...
# 7555       1             1   41          2           0              0.0
# 7556       1             0   22          0           9              0.0
# 7557       1             0   35          0           4              3.0
# 7558       0             0   27          2           5              1.0
# 7559       1             1   37          2           4              0.0
#
#       Spending_Score  Family_Size  Var_1  Segmentation
# ...

# %%
df["Segmentation"].value_counts()
# Out:
# 3    2047
# 0    1910
# 2    1805
# 1    1798
# Name: Segmentation, dtype: int64

# %%
y = df["Segmentation"]
x = df.drop(["Segmentation"], axis=1)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, train_size=0.8, shuffle=True, random_state=42)

# %%
scaler = MinMaxScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
params = {
    "n_estimators" : [ 320],
    "max_depth": [6],
    "max_features": [ "sqrt"],
    "class_weight": [None, "balanced"]
}

grid = GridSearchCV(rfc, param_grid=params, cv=6, scoring="accuracy", verbose=True)

grid.fit(xtrain, ytrain)
# Out:
# Fitting 6 folds for each of 2 candidates, totalling 12 fits
# GridSearchCV(cv=6, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': [None, 'balanced'], 'max_depth': [6],
#                          'max_features': ['sqrt'], 'n_estimators': [320]},
#              scoring='accuracy', verbose=True)

# %%
print(grid.best_params_)
# Out:
# {'class_weight': None, 'max_depth': 6, 'max_features': 'sqrt', 'n_estimators': 320}

# %%
ypred = grid.best_estimator_.predict(xtest)
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.52      0.48       373
#            1       0.35      0.26      0.30       349
#            2       0.56      0.54      0.55       368
#            3       0.64      0.73      0.68       422
#
#     accuracy                           0.52      1512
#    macro avg       0.50      0.51      0.50      1512
# weighted avg       0.51      0.52      0.51      1512

# %%
x.to_csv("clustering.csv")
