# %%
import pandas as pd 
import tensorflow
from tensorflow import keras
from keras import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

df = pd.read_csv("Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df = df.drop(["RowNumber", "CustomerId", "Surname"], axis=1)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
le = LabelEncoder()
for col in df.select_dtypes("object"):
    df[col] = le.fit_transform(df[col])
df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
Y = df["Exited"]
X = df.drop(["Exited"], axis=1)
Xtrain, Xtest,ytrain,ytest = train_test_split(X,Y, test_size=0.2, shuffle=True, random_state=42)

# %%
#scaling es muy importante para gardient descent en NN, SVM, distance measurementes, knn 
scaler = MinMaxScaler()
#important to apply it after splitting bc it affects data leakage and overfitting if combined with xtest , por eso debe ser independiente
Xtrain = scaler.fit_transform(Xtrain)
#se aplican los parameters learned from the training set
Xtest = scaler.transform(Xtest)

# %%
import tensorflow as tf
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.utils import class_weight
import numpy as np


unique_classes = np.unique(ytrain)

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='recall',    # Metric to monitor
    patience=4,            # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

model = Sequential()
model.add(Dense(units=500,  activation="relu"))
model.add(Dropout(0.4))
model.add(Dense(units=400, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(units=400, activation="relu"))
model.add(Dense(units=400, activation="relu"))
model.add(Dense(units=100, activation="relu"))
model.add(Dense(units=1, activation="sigmoid"))

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["recall"])
model.fit(x=Xtrain, y=ytrain, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.5089 - recall: 4.5575e-04 - val_loss: 0.4327 - val_recall: 0.0683
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4714 - recall: 0.1267 - val_loss: 0.4167 - val_recall: 0.1925
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4362 - recall: 0.2475 - val_loss: 0.3985 - val_recall: 0.2826
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4100 - recall: 0.3054 - val_loss: 0.3760 - val_recall: 0.3292
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4004 - recall: 0.3071 - val_loss: 0.3659 - val_recall: 0.3602
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3736 - recall: 0.3548 - val_loss: 0.3770 - val_recall: 0.2919
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3677 - recall: 0.3894 - val_loss: 0.3615 - val_recall: 0.3820
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3580 - recall: 0.4230 - val_loss: 0.3536 - val_recall: 0.3758
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3854 - recall: 0.3610 - val_loss: 0.3630 - val_recall: 0.4379
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3671 - recall: 0.4208 - val_loss: 0.3583 - val_recall: 0.3696
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3752 - recall: 0.4106 - val_loss: 0.3659 - val_recall: 0.3540
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3599 - recall: 0.4122 - val_loss: 0.3592 - val_recall: 0.3292
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3591 - recall: 0.3908 - val_loss: 0.3793 - val_recall: 0.3261
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3535 - recall: 0.4403 - val_loss: 0.3568 - val_recall: 0.3540
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3402 - recall: 0.4126 - val_loss: 0.3606 - val_recall: 0.4255
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3343 - recall: 0.4464 - val_loss: 0.3535 - val_recall: 0.3913
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3571 - recall: 0.4145 - val_loss: 0.3517 - val_recall: 0.3944
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3492 - recall: 0.4200 - val_loss: 0.3483 - val_recall: 0.3882
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3523 - recall: 0.4210 - val_loss: 0.3500 - val_recall: 0.3758
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3308 - recall: 0.4556 - val_loss: 0.3552 - val_recall: 0.3634
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3560 - recall: 0.4229 - val_loss: 0.3558 - val_recall: 0.3354
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3487 - recall: 0.4417 - val_loss: 0.3536 - val_recall: 0.3789
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3347 - recall: 0.4588 - val_loss: 0.3495 - val_recall: 0.4596
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3443 - recall: 0.4700 - val_loss: 0.3510 - val_recall: 0.4255
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3425 - recall: 0.4633 - val_loss: 0.3628 - val_recall: 0.4006
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3441 - recall: 0.4521 - val_loss: 0.3514 - val_recall: 0.4317
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3388 - recall: 0.4835 - val_loss: 0.3523 - val_recall: 0.4720
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3472 - recall: 0.4840 - val_loss: 0.3481 - val_recall: 0.4099
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3482 - recall: 0.4699 - val_loss: 0.3527 - val_recall: 0.4317
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3440 - recall: 0.4349 - val_loss: 0.3515 - val_recall: 0.3758
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3347 - recall: 0.4452 - val_loss: 0.3502 - val_recall: 0.4006

# %%
loss, recall = model.evaluate(Xtest, ytest)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3459 - recall: 0.4840

# %%
ypred = (model.predict(Xtest) > 0.5).astype("int32")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
ypred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      1607
#            1       0.71      0.49      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.80      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
